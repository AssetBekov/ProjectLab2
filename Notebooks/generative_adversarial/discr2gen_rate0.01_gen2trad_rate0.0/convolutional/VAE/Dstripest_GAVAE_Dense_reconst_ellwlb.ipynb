# %%
# !pip -q install colorlog
# !pip -q install keras_radam
# !pip -q install keras_tqdm
#!pip install tensorflow==2.1.0-rc1
# !pip install tensorflow==2.1.0 

# !pip install tensorflow_probability==0.8.0
# Out:
#   Building wheel for keras-radam (setup.py) ... done
# Collecting tensorflow==2.1.0
#   Downloading https://files.pythonhosted.org/packages/85/d4/c0cd1057b331bc38b65478302114194bd8e1b9c2bbc06e300935c0e93d90/tensorflow-2.1.0-cp36-cp36m-manylinux2010_x86_64.whl (421.8MB)
#      |██████▉                         | 89.6MB 1.5MB/s eta 0:03:49ERROR: Exception:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/cli/base_command.py", line 153, in _main
#     status = self.run(options, args)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/commands/install.py", line 382, in run
#     resolver.resolve(requirement_set)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/legacy_resolve.py", line 201, in resolve
#     self._resolve_one(requirement_set, req)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/legacy_resolve.py", line 365, in _resolve_one
#     abstract_dist = self._get_abstract_dist_for(req_to_install)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/legacy_resolve.py", line 313, in _get_abstract_dist_for
#     req, self.session, self.finder, self.require_hashes
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/operations/prepare.py", line 194, in prepare_linked_requirement
#     progress_bar=self.progress_bar
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/download.py", line 465, in unpack_url
#     progress_bar=progress_bar
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/download.py", line 316, in unpack_http_url
#     progress_bar)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/download.py", line 551, in _download_http_url
#     _download_url(resp, link, content_file, hashes, progress_bar)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/download.py", line 253, in _download_url
#     hashes.check_against_chunks(downloaded_chunks)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/utils/hashes.py", line 80, in check_against_chunks
#     for chunk in chunks:
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/download.py", line 223, in written_chunks
#     for chunk in chunks:
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/utils/ui.py", line 162, in iter
#     self.next(n)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_vendor/progress/__init__.py", line 120, in next
#     self.update()
#   File "/usr/local/lib/python3.6/dist-packages/pip/_vendor/progress/bar.py", line 83, in update
#     self.writeln(line)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_vendor/progress/__init__.py", line 101, in writeln
#     self.clearln()
#   File "/usr/local/lib/python3.6/dist-packages/pip/_vendor/progress/__init__.py", line 90, in clearln
#     print('\r\x1b[K', end='', file=self.file)
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/utils/ui.py", line 118, in handle_sigint
#     self.finish()
#   File "/usr/local/lib/python3.6/dist-packages/pip/_internal/utils/ui.py", line 108, in finish
#     super(InterruptibleMixin, self).finish()
#   File "/usr/local/lib/python3.6/dist-packages/pip/_vendor/progress/__init__.py", line 107, in finish
#     print(file=self.file)
# RuntimeError: reentrant call inside <_io.BufferedWriter name='<stdout>'>
# Collecting tensorflow_probability==0.8.0
#   Downloading https://files.pythonhosted.org/packages/f8/72/29ef1e5f386b65544d4e7002dfeca1e55b099ed182cd6d405c21a19ae259/tensorflow_probability-0.8.0-py2.py3-none-any.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 4.8MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow_probability==0.8.0) (1.12.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow_probability==0.8.0) (1.18.4)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from tensorflow_probability==0.8.0) (4.4.2)
# Collecting gast<0.3,>=0.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting cloudpickle==1.1.1
#   Downloading https://files.pythonhosted.org/packages/24/fb/4f92f8c0f40a0d728b4f3d5ec5ff84353e705d8ff5e3e447620ea98b06bd/cloudpickle-1.1.1-py2.py3-none-any.whl
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=802f9dd1f188d3b224b15db01d0a469aca3b24584d7eacecd95b714eeca1f74c
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.2.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: gym 0.17.2 has requirement cloudpickle<1.4.0,>=1.2.0, but you'll have cloudpickle 1.1.1 which is incompatible.
# Installing collected packages: gast, cloudpickle, tensorflow-probability
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Found existing installation: tensorflow-probability 0.10.0
#     Uninstalling tensorflow-probability-0.10.0:
#       Successfully uninstalled tensorflow-probability-0.10.0
# Successfully installed cloudpickle-1.1.1 gast-0.2.2 tensorflow-probability-0.8.0

# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# /

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0

# %%
os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
print(os.getcwd())
# Out:
# /

# %%
# %cd /content/
# !git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# Out:
# /content
# Cloning into 'Generative_Models'...
# remote: Enumerating objects: 2015, done.
# remote: Counting objects: 100% (2015/2015), done.
# remote: Compressing objects: 100% (549/549), done.
# remote: Total 14839 (delta 1467), reused 1866 (delta 1349), pack-reused 12824
# Receiving objects: 100% (14839/14839), 414.64 MiB | 40.24 MiB/s, done.
# Resolving deltas: 100% (10068/10068), done.
# Checking out files: 100% (1674/1674), done.
# /content/Generative_Models

# %%
os.chdir('/content/Generative_Models/')
print(os.getcwd())
# Out:
# /content/Generative_Models

# %% [markdown]
# # Dataset loading

# %%
dataset_name = 'dsprites'
import tensorflow_datasets as tfds

info = tfds.builder(dataset_name).info

print(info)
# Out:
# tfds.core.DatasetInfo(
#     name='dsprites',
#     version=2.0.0,
#     description='dSprites is a dataset of 2D shapes procedurally generated from 6 ground truth
# independent latent factors. These factors are *color*, *shape*, *scale*,
# *rotation*, *x* and *y* positions of a sprite.
#
# All possible combinations of these latents are present exactly once,
# generating N = 737280 total images.
#
# ### Latent factor values
#
# *   Color: white
# *   Shape: square, ellipse, heart
# *   Scale: 6 values linearly spaced in [0.5, 1]
# *   Orientation: 40 values in [0, 2 pi]
# *   Position X: 32 values in [0, 1]
# *   Position Y: 32 values in [0, 1]
#
# We varied one latent at a time (starting from Position Y, then Position X, etc),
# and sequentially stored the images in fixed order.
# Hence the order along the first dimension is fixed and allows you to map back to
# the value of the latents corresponding to that image.
#
# We chose the latents values deliberately to have the smallest step changes
# while ensuring that all pixel outputs were different. No noise was added.
# ',
#     homepage='https://github.com/deepmind/dsprites-dataset',
#     features=FeaturesDict({
#         'image': Image(shape=(64, 64, 1), dtype=tf.uint8),
#         'label_orientation': ClassLabel(shape=(), dtype=tf.int64, num_classes=40),
#         'label_scale': ClassLabel(shape=(), dtype=tf.int64, num_classes=6),
#         'label_shape': ClassLabel(shape=(), dtype=tf.int64, num_classes=3),
#         'label_x_position': ClassLabel(shape=(), dtype=tf.int64, num_classes=32),
#         'label_y_position': ClassLabel(shape=(), dtype=tf.int64, num_classes=32),
#         'value_orientation': tf.float32,
#         'value_scale': tf.float32,
#         'value_shape': tf.float32,
#         'value_x_position': tf.float32,
#         'value_y_position': tf.float32,
#     }),
#     total_num_examples=737280,
#     splits={
#         'train': 737280,
#     },
#     supervised_keys=None,
#     citation="""@misc{dsprites17,
#     author = {Loic Matthey and Irina Higgins and Demis Hassabis and Alexander Lerchner},
#     title = {dSprites: Disentanglement testing Sprites dataset},
#     howpublished= {https://github.com/deepmind/dsprites-dataset/},
#     year = "2017",
#     }""",
#     redistribution_info=,
# )

# %%
intermediate_dim = 20
inputs_shape=(64, 64, 1) # image shape
batch_size = 32
latents_dim = 6

# %%
TRAIN_BUF = 600
TEST_BUF = 100

# %%
import tensorflow_datasets as tfds
# Construct a tf.data.Dataset
train_ds = tfds.load(name=dataset_name, split=tfds.Split.TRAIN).shuffle(TRAIN_BUF).batch(batch_size)
try:
    test_ds = tfds.load(name=dataset_name, split=tfds.Split.TEST).shuffle(TEST_BUF).batch(batch_size)
except:
    test_ds = tfds.load(name=dataset_name, split=tfds.Split.TRAIN).shuffle(TEST_BUF).batch(batch_size)
# Out:
# Downloading and preparing dataset dsprites/2.0.0 (download: 26.73 MiB, generated: Unknown size, total: 26.73 MiB) to /root/tensorflow_datasets/dsprites/2.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/dsprites/2.0.0.incompletePU3D11/dsprites-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=737280.0), HTML(value='')))
# Dataset dsprites downloaded and prepared to /root/tensorflow_datasets/dsprites/2.0.0. Subsequent calls will reuse this data.

# %%
from data.gt_load.datasets import load

# %%
#DATA_DOWN_PATH = '..'+sep_local+'..'+sep_local+'..'+sep_local+'data'
DATA_DOWN_PATH = os.getcwd() + sep_local+'data'
Script_dir = os.getcwd() + sep_local+'data'+sep_local+'download_gt_data.sh'
# Script call to download "dsprites_full" dataset_name 
# !/bin/bash $Script_dir -f $DATA_DOWN_PATH -d $dataset_name
# Out:
# Downloading dSprites dataset.
# --2020-05-20 10:27:35--  https://github.com/deepmind/dsprites-dataset/raw/master/dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/deepmind/dsprites-dataset/master/dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz [following]
# --2020-05-20 10:27:36--  https://raw.githubusercontent.com/deepmind/dsprites-dataset/master/dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19318135 (18M) [application/octet-stream]
# Saving to: ‘/content/Generative_Models/data/.gt_datasets/dsprites/dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz’
#
# /content/Generative 100%[===================>]  18.42M  36.1MB/s    in 0.5s
#
# 2020-05-20 10:27:40 (36.1 MB/s) - ‘/content/Generative_Models/data/.gt_datasets/dsprites/dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz’ saved [19318135/19318135]
#
# Downloading dSprites completed!

# %%
DATA_PATH =  os.getcwd() + sep_local+'data' +sep_local+'.gt_datasets'
#absolute = abspath(DATA_PATH)
print(DATA_PATH)
# Out:
# /content/Generative_Models/data/.gt_datasets

# %%
# !ls /content/Generative_Models/data/.gt_datasets/dsprites
# Out:
# dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz

# %%
eval_dataset = load(dataset_name='dsprites_full',dataset_path=DATA_PATH)

# %%
_instance_scale=1.0
for data in train_ds:
    _instance_scale = float(data['image'].numpy().max())
    break

# %%
_instance_scale
# Out:
# 1.0

# %%
import numpy as np
from collections.abc import Iterable

# %%
if isinstance(inputs_shape, Iterable):
    _outputs_shape = np.prod(inputs_shape)

# %%
_outputs_shape
# Out:
# 4096

# %% [markdown]
# # Model's Layers definition

# %%
units=intermediate_dim
c=50
menc_lays = [
    tf.keras.layers.Conv2D(filters=units, kernel_size=1, strides=(2, 2), activation='relu'),
    tf.keras.layers.Flatten(),
    # No activation
    tf.keras.layers.Dense(latents_dim)
]

venc_lays = [
    tf.keras.layers.Conv2D(filters=units, kernel_size=1, strides=(2, 2), activation='relu'),
    tf.keras.layers.Flatten(),
    # No activation
    tf.keras.layers.Dense(latents_dim)
]

dec_lays = [
    tf.keras.layers.Dense(units=units*c*c, activation=tf.nn.relu),
    tf.keras.layers.Reshape(target_shape=(c , c, units)),
    tf.keras.layers.Conv2DTranspose(filters=units*3, kernel_size=3, strides=(4, 4), padding="SAME", activation='relu'),
    # No activation
    tf.keras.layers.Conv2DTranspose(filters=3, kernel_size=3, strides=(1, 1), padding="SAME")
]

# %% [markdown]
# # Model definition

# %%
from google.colab import drive
drive.mount('/content/drive')
#!mkdir /content/drive/My\ Drive/DstResults/
MAIN_SAVE_DIR = '/content/drive/My Drive/DstResults'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
model_name = dataset_name+'GAVAE_Dense_reconst_ell'
#experiments_dir='experiments'+sep_local+model_name
recording_dir=MAIN_SAVE_DIR + sep_local  +'recording-Dense'+sep_local + model_name

# %%
from training.adversarial_basic.generative_adversarial.autoencoders.VAAE import VAAE as AE

# %%
variables_params = \
[
    {
        'name': 'inference_mean', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': menc_lays
    },
    
    {
        'name': 'inference_logvariance', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': venc_lays
    },
        {
        'name': 'generative', 
        'inputs_shape':latents_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(recording_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '/content/drive/My Drive/DstResults/recording-Dense/dspritesGAVAE_Dense_reconst_ell/var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    latents_dim=latents_dim,
    batch_size=batch_size,
    variables_params=variables_params, 
    filepath=None
    )
# Out:
#   WARNING  | None
#   WARNING  | None
# Model: "inference_mean"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_mean_inputs (Input [(None, 64, 64, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 20)        40
# _________________________________________________________________
# flatten (Flatten)            (None, 20480)             0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 122886
# _________________________________________________________________
# batch_normalization (BatchNo (None, 6)                 24
# _________________________________________________________________
# dropout (Dropout)            (None, 6)                 0
# _________________________________________________________________
# activity_regularization (Act (None, 6)                 0
# _________________________________________________________________
# inference_mean_outputs (Acti (None, 6)                 0
# =================================================================
# Total params: 122,950
# Trainable params: 122,938
# Non-trainable params: 12
# _________________________________________________________________
#
# Model: "inference_logvariance"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_logvariance_inputs [(None, 64, 64, 1)]       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 20)        40
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 20480)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 122886
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 6)                 24
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# activity_regularization_1 (A (None, 6)                 0
# _________________________________________________________________
# inference_logvariance_output (None, 6)                 0
# =================================================================
# Total params: 122,950
# Trainable params: 122,938
# Non-trainable params: 12
# _________________________________________________________________
#   WARNING  | None
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 6)]               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50000)             350000
# _________________________________________________________________
# reshape (Reshape)            (None, 50, 50, 20)        0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 200, 200, 60)      10860
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 200, 200, 3)       1623
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 200, 200, 3)       12
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200, 200, 3)       0
# _________________________________________________________________
# activity_regularization_2 (A (None, 200, 200, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 200, 200, 3)       0
# =================================================================
# Total params: 362,495
# Trainable params: 362,489
# Non-trainable params: 6
# _________________________________________________________________

# %%
from statistical.basic_adversarial_losses import \
    create_generative_discriminator_real_losses, \
    create_generative_discriminator_fake_losses, \
    create_generative_generator_fake_losses
    

generative_discriminator_losses = {
    'generative_discriminator_real_outputs': create_generative_discriminator_real_losses,
    'generative_discriminator_fake_outputs': create_generative_discriminator_fake_losses,
    'generative_generator_fake_outputs': create_generative_generator_fake_losses,
}

# %%
#ae.compile(metrics=None)
discr2gen_rate = 0.001
gen2trad_rate = 0.1

ae.compile(
    adversarial_losses=generative_discriminator_losses,
    adversarial_weights={'generator_weight': gen2trad_rate, 'discriminator_weight': discr2gen_rate}
)
# Out:
# WARNING:tensorflow:Output inference_logvariance missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to inference_logvariance.
# WARNING:tensorflow:Output inference_logvariance missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to inference_logvariance.
# WARNING:tensorflow:Output inference_mean missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to inference_mean.
# WARNING:tensorflow:Output inference_mean missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to inference_mean.
# Model: "dspritesGAVAE_Dense_reconst_ell"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inference_logvariance_inputs (I [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# inference_logvariance (Model)   (None, 6)            122950      inference_logvariance_inputs[0][0
# __________________________________________________________________________________________________
# tf_op_layer_mul (TensorFlowOpLa [(None, 6)]          0           inference_logvariance[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, 6)]          0           tf_op_layer_mul[0][0]
# __________________________________________________________________________________________________
# inference_mean_inputs (InputLay [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# tf_op_layer_mul_1 (TensorFlowOp [(32, 6)]            0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# inference_mean (Model)          (None, 6)            122950      inference_mean_inputs[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(None, 6)]          0           inference_logvariance[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_z_latents (TensorFl [(32, 6)]            0           tf_op_layer_mul_1[0][0]
#                                                                  inference_mean[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sqrt (TensorFlowOpL [(None, 6)]          0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv (TensorFlow [(32, 6)]            0           tf_op_layer_z_latents[0][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_truediv_1 (TensorFl [(None, 6)]          0           inference_mean[1][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SquaredDifference ( [(32, 6)]            0           tf_op_layer_truediv[0][0]
#                                                                  tf_op_layer_truediv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(None, 6)]          0           tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_2 (TensorFlowOp [(32, 6)]            0           tf_op_layer_SquaredDifference[0][
# __________________________________________________________________________________________________
# tf_op_layer_add (TensorFlowOpLa [(None, 6)]          0           tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub (TensorFlowOpLa [(32, 6)]            0           tf_op_layer_mul_2[0][0]
#                                                                  tf_op_layer_add[0][0]
# __________________________________________________________________________________________________
# generative (Model)              multiple             362495      tf_op_layer_z_latents[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_logpdf (TensorFlowO [(32, 6)]            0           tf_op_layer_sub[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_x_logits (TensorFlo [(32, 200, 200, 3)]  0           generative[1][0]
# ==================================================================================================
# Total params: 608,395
# Trainable params: 608,365
# Non-trainable params: 30
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver
from training.callbacks.disentangle_supervied import DisentanglementSuperviedMetrics
from training.callbacks.disentangle_unsupervied import DisentanglementUnsuperviedMetrics

# %%
gts_csv = os.path.join(recording_dir, 'csv_dir', 'gts_metrics')
gtu_csv = os.path.join(recording_dir, 'csv_dir', 'gtu_metrics')

# %%
gts_mertics = DisentanglementSuperviedMetrics(            
    ground_truth_data=eval_dataset,
    representation_fn=lambda x: ae.encode(x),
    random_state=np.random.RandomState(0),
    file_Name=gts_csv,
    num_train=10000,
    num_test=200,
    batch_size=batch_size,
    continuous_factors=False,
    gt_freq=10
)
gtu_mertics = DisentanglementUnsuperviedMetrics(            
    ground_truth_data=eval_dataset,
    representation_fn=lambda x: ae.encode(x),
    random_state=np.random.RandomState(0),
    file_Name=gtu_csv,
    num_train=10000,
    num_test=200,
    batch_size=batch_size,
    gt_freq=10
)

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='loss', 
    min_delta=1e-12, 
    patience=5, 
    verbose=1, 
    restore_best_weights=True
)

# %%
ms = ModelSaver(filepath=_restore,save_freq=5)

# %%
csv_dir = os.path.join(recording_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '/content/drive/My Drive/DstResults/recording-Dense/dspritesGAVAE_Dense_reconst_ell/csv_dir/dspritesGAVAE_Dense_reconst_ell.csv'

# %%
image_gen_dir = os.path.join(recording_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latents_shape=latents_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=True)

# %%
import numpy as np

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_ds,
    input_kw='image',
    steps_per_epoch=1000,
    epochs=int(1e6), 
    verbose=2,
    callbacks=[ es, ms, csv_log, sg, gts_mertics, gtu_mertics],
    workers=-1,
    use_multiprocessing=True,
    validation_data=test_ds,
    validation_steps=1000
)
# Out:
# training <class 'training.autoencoding_basic.autoencoders.VAE.VAE'>
# Train for 1000 steps, validate for 1000 steps
# Epoch 1/1000000
# WARNING:tensorflow:Early stopping conditioned on metric `loss` which is not available. Available metrics are:
# WARNING:tensorflow:Early stopping conditioned on metric `loss` which is not available. Available metrics are:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-41-035af6381333> in <module>()
#       9     use_multiprocessing=True,
#      10     validation_data=test_ds,
# ---> 11     validation_steps=1000
#      12 )
#
# /content/Generative_Models/training/adversarial_basic/generative_adversarial/autoencoders/VAAE.py in fit(self, x, validation_data, **kwargs)
#      79             x=x,
#      80             validation_data=validation_data,
# ---> 81             **kwargs
#      82         )
#      83
#
# /content/Generative_Models/training/autoencoding_basic/autoencoders/autoencoder.py in fit(self, x, y, input_kw, input_scale, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_split, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     127                 use_multiprocessing=use_multiprocessing,
#     128                 shuffle=shuffle,
# --> 129                 initial_epoch=initial_epoch
#     130             )
#     131
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      97                 value = type()
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#     101                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2.py in on_start(self, model, callbacks, use_samples, verbose, mode)
#     755     finally:
#     756       # End of all epochs
# --> 757       self.callbacks._call_end_hook(mode)
#     758
#     759   @tf_contextlib.contextmanager
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/callbacks.py in _call_end_hook(self, mode)
#     260     """Helper function for on_{train|test|predict}_end methods."""
#     261     if mode == ModeKeys.TRAIN:
# --> 262       self.on_train_end()
#     263     elif mode == ModeKeys.TEST:
#     264       self.on_test_end()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/callbacks.py in on_train_end(self, logs)
#     377     """
#     378     for callback in self.callbacks:
# --> 379       callback.on_train_end(logs)
#     380
#     381   def on_test_begin(self, logs=None):
#
# /content/Generative_Models/training/callbacks/sample_generation.py in on_train_end(self, logs)
#      25
#      26     def on_train_end(self, logs=None):
# ---> 27         self.generate(-999, logs)
#      28
#      29     def on_epoch_end(self, epoch, logs={}):
#
# /content/Generative_Models/training/callbacks/sample_generation.py in generate(self, epoch, logs)
#      35                                                input_shape=self.model.get_inputs_shape(),
#      36                                                latents_shape=[50, self.model.latents_dim],
# ---> 37                                                epsilon=self.random_latents)
#      38         plot_and_save_generated(generated=generated, epoch=epoch, path=self.filepath, gray=self.gray_plot,
#      39                                 save=self.save_img)
#
# /content/Generative_Models/graphs/basics/AE_graph.py in generate_sample(model, input_shape, latents_shape, epsilon)
#      58     if epsilon is None:
#      59         epsilon = tf.random.normal(shape=latents_shape)
# ---> 60     generated = decode_fn(model=model, latents=epsilon, output_shape=input_shape, apply_sigmoid=True)
#      61     return generated
#
# /content/Generative_Models/graphs/basics/AE_graph.py in decode_fn(model, latents, output_shape, apply_sigmoid)
#      52     if apply_sigmoid:
#      53         probs = tf.sigmoid(x_logits)
# ---> 54         return tf.reshape(tensor=probs, shape=[-1] + [*output_shape], name='x_probablities')
#      55     return tf.reshape(tensor=x_logits, shape=[-1] + [*output_shape], name='x_logits')
#      56
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/array_ops.py in reshape(tensor, shape, name)
#     191     A `Tensor`. Has the same type as `tensor`.
#     192   """
# --> 193   result = gen_array_ops.reshape(tensor, shape, name)
#     194   tensor_util.maybe_set_static_shape(result, shape)
#     195   return result
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/gen_array_ops.py in reshape(tensor, shape, name)
#    7434       try:
#    7435         return reshape_eager_fallback(
# -> 7436             tensor, shape, name=name, ctx=_ctx)
#    7437       except _core._SymbolicException:
#    7438         pass  # Add nodes to the TensorFlow graph.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/gen_array_ops.py in reshape_eager_fallback(tensor, shape, name, ctx)
#    7461   _attrs = ("T", _attr_T, "Tshape", _attr_Tshape)
#    7462   _result = _execute.execute(b"Reshape", 1, inputs=_inputs_flat, attrs=_attrs,
# -> 7463                              ctx=ctx, name=name)
#    7464   if _execute.must_record_gradient():
#    7465     _execute.record_gradient(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# /usr/local/lib/python3.6/dist-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: Input to reshape is a tensor with 6000000 values, but the requested shape requires a multiple of 4096 [Op:Reshape] name: x_probablities

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## inception_score

# %%
from evaluation.generativity_metrics.inception_metrics import inception_score

# %%
is_mean, is_sigma = inception_score(ae, tolerance_threshold=1e-6, max_iteration=200)
print(f'inception_score mean: {is_mean}, sigma: {is_sigma}')

# %% [markdown]
# ## Frechet_inception_distance

# %%
from evaluation.generativity_metrics.inception_metrics import frechet_inception_distance

# %%
fis_score = frechet_inception_distance(ae, training_generator, tolerance_threshold=1e-6, max_iteration=10, batch_size=32)
print(f'frechet inception distance: {fis_score}')

# %% [markdown]
# ## perceptual_path_length_score

# %%
from evaluation.generativity_metrics.perceptual_path_length import perceptual_path_length_score

# %%
ppl_mean_score = perceptual_path_length_score(ae, training_generator, tolerance_threshold=1e-6, max_iteration=200, batch_size=32)
print(f'perceptual path length score: {ppl_mean_score}')

# %% [markdown]
# ## precision score

# %%
from evaluation.generativity_metrics.precision_recall import precision_score

# %%
_precision_score = precision_score(ae, training_generator, tolerance_threshold=1e-6, max_iteration=200)
print(f'precision score: {_precision_score}')

# %% [markdown]
# ## recall score

# %%
from evaluation.generativity_metrics.precision_recall import recall_score

# %%
_recall_score = recall_score(ae, training_generator, tolerance_threshold=1e-6, max_iteration=200)
print(f'recall score: {_recall_score}')

# %% [markdown]
# # Image Generation

# %% [markdown]
# ## image reconstruction

# %% [markdown]
# ### Training dataset

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from training.generators.image_generation_testing import reconstruct_from_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(recording_dir, 'reconstruct_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, training_generator, save_dir)

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(recording_dir, 'reconstruct_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, testing_generator, save_dir)

# %% [markdown]
# ## with Randomness

# %%
from training.generators.image_generation_testing import generate_images_like_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, training_generator, save_dir)

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, testing_generator, save_dir)

# %% [markdown]
# ### Complete Randomness

# %%
from training.generators.image_generation_testing import generate_images_randomly

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'random_synthetic_dir')
create_if_not_exist(save_dir)

generate_images_randomly(ae, save_dir)

# %%
from training.generators.image_generation_testing import interpolate_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'interpolate_dir')
create_if_not_exist(save_dir)

interpolate_a_batch(ae, testing_generator, save_dir)
